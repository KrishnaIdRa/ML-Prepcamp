# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
points = np.random.uniform(100,size=(1000,2))
points = points.round(2)

# %%
points
# Out:
# array([[50.97, 65.36],
#        [63.74, 80.61],
#        [67.07, 25.09],
#        ...,
#        [40.67, 40.58],
#        [ 5.63, 98.82],
#        [11.88, 38.11]])

# %%
df=pd.DataFrame(points)

# %%
df
# Out:
#          0      1
# 0    50.97  65.36
# 1    63.74  80.61
# 2    67.07  25.09
# 3    85.41  86.13
# 4    38.62  16.04
# ..     ...    ...
# 995  90.94  22.72
# 996  80.62  30.07
# 997  40.67  40.58
# 998   5.63  98.82
# 999  11.88  38.11
#
# [1000 rows x 2 columns]

# %%
r=10

# %%
plt.figure(figsize=(10,10))
plt.scatter(df.iloc[:,0],df.iloc[:,1])
plt.xticks(np.arange(0,101,10))
plt.yticks(np.arange(0,101,10))
plt.grid()
plt.show()

# %%
for row in df.itertuples():
  val1=row['0']
  val2=row['1']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-9-936a1e7ec246> in <cell line: 1>()
#       1 for row in df.itertuples():
# ----> 2   val1=row['0']
#       3   val2=row['1']
#
# TypeError: tuple indices must be integers or slices, not str
